# %%
#Practice 1
first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")
city = input("Enter your city: ")

print(f"\nHi! My name is {first_name} {last_name}, and I am from {city}")
# Out:
# Hi! My name is Sothik Im, and I am from Pp

# %%
#Practice 2
radius = float(input("Enter Radius: "))
height = float(input("Enter Height: "))
PI = 3.14
PI = 3
area = radius * radius * PI
volume = area * height
print("Area: ", area, "Volume: ", volume)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 #Practice 2
# ----> 2 radius = float(input("Enter Radius: "))
#       3 height = float(input("Enter Height: "))
#       4 PI = 3.14
#       5 PI = 3
#
# ValueError: could not convert string to float: ''

# %%
#Practice 3
num1 = int(input("Enter a number: "))
num2 = int(input("Enter a number: "))

print(f"\nThe result of the multiplication is: {num1 * num2}")

# %%
#Practice 4
num1 = int(input("Enter the first number: "))
num2 = int(input("Enter the second number: "))
num3 = int(input("Enter the third number: "))

avg = (num1 + num2 + num3) / 3
print(f"The average of {num1} {num2} {num3} is: {avg}")
